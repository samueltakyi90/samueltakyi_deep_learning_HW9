# %% [markdown]
# Please mount your Google drive, and set up your working folder path here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/Deep Learning/Homework9/Homework9") # change your working folder here
# end your code here

# %% [markdown]
# # Convolutional Neural Networks: Gesture Classification
#
# Welcome to our thrid module! In this notebook, you will:
#
# - Implement a fully functioning ConvNet using TensorFlow
#
# **After this assignment you will be able to:**
#
# - Build and train a ConvNet in TensorFlow for a classification problem
#
# We assume here that you are already familiar with TensorFlow.

# %% [markdown]
# ## 1.0 - TensorFlow model
#
# As usual, we will start by loading in the packages.

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
import tensorflow as tf
from tensorflow.python.framework import ops
from tensorflow.keras import datasets, layers, models
from cnn_utils import *

# %matplotlib inline
np.random.seed(1)
tf.random.set_seed(1234)

# %% [markdown]
# Run the next cell to load the "SIGNS" dataset you are going to use.

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.
#
# ![alt text](https://drive.google.com/uc?id=1db9mIM_lD4StTKhab9nfLfdCSLjXG3Cf)
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of a picture
index = 1000
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 2

# %% [markdown]
# To get started, let's examine the shapes of your data.

# %%
# what do the following two lines do?
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Next, we will convert the value 0,1,2,3,4,5 to a one-hot column. 
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
conv_layers = {}
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# ### 1.1 - Create the convolutional base
#
# In TensorFlow, there are built-in functions that carry out the convolution steps for you.
#
# - **tf.keras.models.Sequential()** groups a linear stack of layers into a neural networt model. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential)
# - **tf.keras.layers.Conv2D(filters, kernel_size, strides=(1, 1), padding='valid', activation=None, input_shape=(32, 32, 3), kernel_initializer='glorot_uniform'):** 'filters' specifies the number of filters in this Conv layer. 'kernel_size' indicates the height and the width of the filters, e.g., (3,3) means a 3 by 3 filter. The third input 'strides' represents the strides for the height and the width of the input (n_H_prev, n_W_prev) with default value (1,1). 'padding' can be 'valid'(default) or 'same'. You can choose your activation function in the input 'activation'. You may want to specify your image shape in 'input_shape'. (32,32,3) means this is a 32 by 32 RGB image. 'kernel_initializer' specifies how you want to initialize your filter. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
# - **tf.keras.layers.MaxPooling2D(pool_size=(f, f), strides=(s,s), padding='valid'):** this function uses a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D)
#
# **Exercise**:
#
# Build the following model: `CONV2D -> MAXPOOL -> CONV2D -> MAXPOOL`. You should use the functions above.
#
# In detail, we will use the following parameters for all the steps:
#
#      - Conv2D: 8 filters with size (4,4), stride 1, padding is "same", activation function is 'Relu', input_shape=(64,64,3), filter initializer is 'glorot_uniform'
#      - Max pool: Use an 8 by 8 filter size and an 8 by 8 stride, padding is "same"
#      - Conv2D: 16 filters with size (2,2), stride 1, padding is "same", activation function is 'Relu', filter initializer is 'glorot_uniform', input shape will be decided automatically
#      - Max pool: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "same"

# %%
# GRADED steps

model = models.Sequential()
#add a conv layer: 8 filters with size (4,4), stride (1,1), padding is 'same', activation function is 'relu', input_shape=(64,64,3), filter initializer is 'glorot_uniform'
model.add(tf.keras.layers.Conv2D(8,
                                 (4,4),
                                 strides=(1,1), 
                                 padding='same', activation='relu', 
                                 input_shape=(64,64,3), 
                                 kernel_initializer='glorot_uniform',
                                 kernel_regularizer=tf.keras.regularizers.L2(0.01)))
#add a MAXPOOL layer: window 8x8, sride (8,8), padding 'same'
model.add(tf.keras.layers.MaxPooling2D(pool_size=(8,8), strides=(8,8), padding='same'))

### START CODE HERE ###
#add the second conv layer: 16 filters with size (2,2), stride (1,1), padding is "same", activation function is 'relu', filter initializer is 'glorot_uniform', input shape will be decided automatically
model.add(tf.keras.layers.Conv2D(16,
                                 (2,2),
                                 strides=(1,1), 
                                 padding='same', activation='relu', 
                                 input_shape=(64,64,3), 
                                 kernel_initializer='glorot_uniform',
                                 kernel_regularizer=tf.keras.regularizers.L2(0.01)))
#add the second MAXPOOL layer: window 4x4, stride (4,4), padding 'same'
model.add(tf.keras.layers.MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
### END CODE HERE ###

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 8)         392
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 8)          0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          528
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
# =================================================================
# Total params: 920
# Trainable params: 920
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Expected Output**:
#
# ![alt text](https://urldefense.com/v3/__https://drive.google.com/uc?id=16G8b6zw23HkPTSmKKboIVqB_ehiDE9BL__;!!PhOWcWs!lj_KcD0A6Xl-_k4Lj8Ll_SLpdbsvdvk2BUHx7Ca3ALRgep71u_2GAgTSv5pO1_y0ZRQV_so$ )

# %% [markdown]
# ### 1.2 - Add Dense layers on top
# To complete our model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. There are built-in functions that carry out these steps for you.
#
# - **tf.keras.layers.Flatten()**: this function flattens each example into a 1D vector while maintaining the batch-size. It returns a flattened tensor with shape [batch_size, k]. You can read the full documentation [here.](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten)
# - **tf.keras.layers.Dense(num_outputs):** It returns the output computed using a fully connected layer. You shall specify the number of outputs in 'num_outputs'. You can read the full documentation [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)
# In the last function above (`tf.keras.layers.Dense`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
# **Exercise**:
#
# Build the fully connected (Dense) layer on the Conv base: `CONV2D -> MAXPOOL -> CONV2D -> MAXPOOL -> FLATTEN -> DENSE`. You should use the functions above.
#
# - Flatten the previous output.
# - FULLYCONNECTED (Dense) layer: Apply a fully connected layer with activation function 'softmax'. Multi-class classification problems usually use 'softmax' as the activation function in the output layer if the target output is a 'one-hot' function.

# %%
# add the FLATTEN layer: tf.keras.layers.Flatten()
model.add(tf.keras.layers.Flatten())

### START CODE HERE ###
# Please add a dense layer with 6 neurons, and activation function 'softmax'
model.add(tf.keras.layers.Dense(6, activation='softmax'))
### END CODE HERE ###

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 8)         392
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 8)          0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          528
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 6)                 390
#
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# As you can see, our (2, 2, 16) outputs were flattened into vectors of shape (64) before going through the Dense layer.
#
# **Expected Output**:
#
# ![alt text](https://urldefense.com/v3/__https://drive.google.com/uc?id=15jEv_qKYS0r95tiXQbcuS6PxlBnKcb4R__;!!PhOWcWs!lj_KcD0A6Xl-_k4Lj8Ll_SLpdbsvdvk2BUHx7Ca3ALRgep71u_2GAgTSv5pO1_y0UEdgN_4$ )

# %% [markdown]
# ### 1.3 - Compile and train the model
# When compiling the model, you will specify the optimizer, the loss function, and the metric you are going to use.
#
# - **compile(optimizer=None, loss=None, metrics=None)** You can check the full documentation  [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/Model*compile)
# - **tf.keras.losses.CategoricalCrossentropy()** You can check the full documentation  [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/losses/CategoricalCrossentropy)
#
# **Exercise**: Compile the model using 'tf.keras.optimizers.Adam(learning_rate=None)' as the optimizer, 'tf.keras.losses.CategoricalCrossentropy()' as the loss function, and 'accuracy' as the metrics.
#
# Now, we are ready to train the model. During the training process, you need to specify training input, training output, epoch number and batch size. The samples will be shuffled by default.
#
# -**model.fit(x=None, y=None, batch_size=None, epochs=1,validation_split=0.0)**
#
# **Exercise**: train the model with epoch number no more than 400.
#
# Please adjust the learning_rate in the adam optimizer and the batch_size in 'model.fit' such that the accuracy of the training set is above 92% at the end of the training.

# %%
# GRADED FUNCTION: compile the model 

# Compile the model using 'adam' as the optimizer, 'tf.keras.losses.CategoricalCrossentropy()' as the loss function, and 'accuracy' as the metrics.

### START CODE HERE ### 
model.compile(optimizer='adam',
          loss=tf.keras.losses.CategoricalCrossentropy(),
          metrics='accuracy')
### END CODE HERE ###

# GRADED FUNCTION: train the model 

# train the model with batch size = 64, and epoch number = 100.

### START CODE HERE ### 
history = model.fit(X_train, Y_train, validation_split=0.2, epochs=250, batch_size=64)
### END CODE HERE ###

## plot the training history
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.ylim([0.5, 1])
plt.legend(loc='lower right')
#print('The training accuracy is', history.history['accuracy'][-1])
# Out:
# Epoch 1/250
# 14/14 [==============================] - 1s 31ms/step - loss: 0.4494 - accuracy: 0.9433 - val_loss: 0.4397 - val_accuracy: 0.9491
# Epoch 2/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4353 - accuracy: 0.9514 - val_loss: 0.4454 - val_accuracy: 0.9537
# Epoch 3/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4376 - accuracy: 0.9491 - val_loss: 0.4488 - val_accuracy: 0.9444
# Epoch 4/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4330 - accuracy: 0.9502 - val_loss: 0.4744 - val_accuracy: 0.9259
# Epoch 5/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4548 - accuracy: 0.9410 - val_loss: 0.4578 - val_accuracy: 0.9306
# Epoch 6/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4367 - accuracy: 0.9560 - val_loss: 0.4633 - val_accuracy: 0.9398
# Epoch 7/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4391 - accuracy: 0.9491 - val_loss: 0.4628 - val_accuracy: 0.9213
# Epoch 8/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4375 - accuracy: 0.9491 - val_loss: 0.4601 - val_accuracy: 0.9306
# Epoch 9/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4337 - accuracy: 0.9491 - val_loss: 0.4640 - val_accuracy: 0.9306
# Epoch 10/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4330 - accuracy: 0.9514 - val_loss: 0.4549 - val_accuracy: 0.9352
# Epoch 11/250
# 14/14 [==============================] - 0s 19ms/step - loss: 0.4324 - accuracy: 0.9549 - val_loss: 0.4601 - val_accuracy: 0.9352
# Epoch 12/250
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4392 - accuracy: 0.9525 - val_loss: 0.4649 - val_accuracy: 0.9213
# Epoch 13/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4416 - accuracy: 0.9456 - val_loss: 0.4563 - val_accuracy: 0.9398
# Epoch 14/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4341 - accuracy: 0.9514 - val_loss: 0.4673 - val_accuracy: 0.9306
# Epoch 15/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4353 - accuracy: 0.9479 - val_loss: 0.4511 - val_accuracy: 0.9491
# Epoch 16/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4304 - accuracy: 0.9560 - val_loss: 0.4570 - val_accuracy: 0.9444
# Epoch 17/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4261 - accuracy: 0.9549 - val_loss: 0.4631 - val_accuracy: 0.9306
# Epoch 18/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4283 - accuracy: 0.9479 - val_loss: 0.4594 - val_accuracy: 0.9306
# Epoch 19/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4285 - accuracy: 0.9525 - val_loss: 0.4586 - val_accuracy: 0.9398
# Epoch 20/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4372 - accuracy: 0.9491 - val_loss: 0.4861 - val_accuracy: 0.9028
# Epoch 21/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.
250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3987 - accuracy: 0.9583 - val_loss: 0.4821 - val_accuracy: 0.9167
# Epoch 156/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3980 - accuracy: 0.9664 - val_loss: 0.4924 - val_accuracy: 0.9074
# Epoch 157/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4030 - accuracy: 0.9606 - val_loss: 0.5115 - val_accuracy: 0.8981
# Epoch 158/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4150 - accuracy: 0.9502 - val_loss: 0.5123 - val_accuracy: 0.8889
# Epoch 159/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4114 - accuracy: 0.9583 - val_loss: 0.5074 - val_accuracy: 0.8981
# Epoch 160/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4032 - accuracy: 0.9641 - val_loss: 0.4842 - val_accuracy: 0.9167
# Epoch 161/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3988 - accuracy: 0.9630 - val_loss: 0.4913 - val_accuracy: 0.9120
# Epoch 162/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3950 - accuracy: 0.9583 - val_loss: 0.4880 - val_accuracy: 0.9213
# Epoch 163/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4030 - accuracy: 0.9560 - val_loss: 0.4783 - val_accuracy: 0.9120
# Epoch 164/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4028 - accuracy: 0.9572 - val_loss: 0.4767 - val_accuracy: 0.9120
# Epoch 165/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4062 - accuracy: 0.9595 - val_loss: 0.4898 - val_accuracy: 0.9167
# Epoch 166/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3984 - accuracy: 0.9549 - val_loss: 0.4797 - val_accuracy: 0.9167
# Epoch 167/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3976 - accuracy: 0.9606 - val_loss: 0.4845 - val_accuracy: 0.9213
# Epoch 168/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4024 - accuracy: 0.9641 - val_loss: 0.5071 - val_accuracy: 0.9120
# Epoch 169/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4080 - accuracy: 0.9549 - val_loss: 0.5177 - val_accuracy: 0.9074
# Epoch 170/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4057 - accuracy: 0.9560 - val_loss: 0.4923 - val_accuracy: 0.9074
# Epoch 171/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3969 - accuracy: 0.9630 - val_loss: 0.4776 - val_accuracy: 0.9213
# Epoch 172/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3936 - accuracy: 0.9618 - val_loss: 0.4895 - val_accuracy: 0.9120
# Epoch 173/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3949 - accuracy: 0.9653 - val_loss: 0.4823 - val_accuracy: 0.9074
# Epoch 174/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4034 - accuracy: 0.9572 - val_loss: 0.5094 - val_accuracy: 0.9028
# Epoch 175/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3985 - accuracy: 0.9606 - val_loss: 0.4830 - val_accuracy: 0.9167
# Epoch 176/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3951 - accuracy: 0.9664 - val_loss: 0.4806 - val_accuracy: 0.9167
# Epoch 177/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3971 - accuracy: 0.9618 - val_loss: 0.4854 - val_accuracy: 0.9259
# Epoch 178/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4149 - accuracy: 0.9514 - val_loss: 0.5011 - val_accuracy: 0.9074
# Epoch 179/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4046 - accuracy: 0.9583 - val_loss: 0.4905 - val_accuracy: 0.9167
# Epoch 180/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4039 - accuracy: 0.9560 - val_loss: 0.5017 - val_accuracy: 0.9028
# Epoch 181/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3948 - accuracy: 0.9618 - val_loss: 0.4870 - val_accuracy: 0.9120
# Epoch 182/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4006 - accuracy: 0.9641 - val_loss: 0.4921 - val_accuracy: 0.9213
# Epoch 183/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4063 - accuracy: 0.9606 - val_loss: 0.4927 - val_accuracy: 0.9074
# Epoch 184/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3952 - accuracy: 0.9688 - val_loss: 0.5031 - val_accuracy: 0.9028
# Epoch 185/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3996 - accuracy: 0.9618 - val_loss: 0.4789 - val_accuracy: 0.9167
# Epoch 186/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3936 - accuracy: 0.9560 - val_loss: 0.4868 - val_accuracy: 0.9259
# Epoch 187/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4009 - accuracy: 0.9560 - val_loss: 0.4788 - val_accuracy: 0.9259
# Epoch 188/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3979 - accuracy: 0.9653 - val_loss: 0.4954 - val_accuracy: 0.9167
# Epoch 189/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3991 - accuracy: 0.9606 - val_loss: 0.4793 - val_accuracy: 0.9120
# Epoch 190/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3938 - accuracy: 0.9630 - val_loss: 0.4809 - val_accuracy: 0.9167
# Epoch 191/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3977 - accuracy: 0.9606 - val_loss: 0.4852 - val_accuracy: 0.9167
# Epoch 192/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3897 - accuracy: 0.9641 - val_loss: 0.4820 - val_accuracy: 0.9074
# Epoch 193/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3983 - accuracy: 0.9572 - val_loss: 0.4819 - val_accuracy: 0.9213
# Epoch 194/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3940 - accuracy: 0.9630 - val_loss: 0.4819 - val_accuracy: 0.9259
# Epoch 195/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3905 - accuracy: 0.9641 - val_loss: 0.4776 - val_accuracy: 0.9120
# Epoch 196/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3948 - accuracy: 0.9630 - val_loss: 0.5012 - val_accuracy: 0.8935
# Epoch 197/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3959 - accuracy: 0.9560 - val_loss: 0.4833 - val_accuracy: 0.9213
# Epoch 198/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3945 - accuracy: 0.9630 - val_loss: 0.4747 - val_accuracy: 0.9120
# Epoch 199/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3889 - accuracy: 0.9641 - val_loss: 0.5013 - val_accuracy: 0.9028
# Epoch 200/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3963 - accuracy: 0.9595 - val_loss: 0.5141 - val_accuracy: 0.9028
# Epoch 201/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3973 - accuracy: 0.9606 - val_loss: 0.4919 - val_accuracy: 0.9213
# Epoch 202/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3925 - accuracy: 0.9583 - val_loss: 0.5147 - val_accuracy: 0.9167
# Epoch 203/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4021 - accuracy: 0.9583 - val_loss: 0.4886 - val_accuracy: 0.9120
# Epoch 204/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4029 - accuracy: 0.9560 - val_loss: 0.5024 - val_accuracy: 0.9167
# Epoch 205/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3929 - accuracy: 0.9641 - val_loss: 0.4879 - val_accuracy: 0.9028
# Epoch 206/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3895 - accuracy: 0.9606 - val_loss: 0.4824 - val_accuracy: 0.9167
# Epoch 207/250
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3966 - accuracy: 0.9537 - val_loss: 0.5149 - val_accuracy: 0.9074
# Epoch 208/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3948 - accuracy: 0.9537 - val_loss: 0.4945 - val_accuracy: 0.9120
# Epoch 209/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3923 - accuracy: 0.9630 - val_loss: 0.5064 - val_accuracy: 0.8981
# Epoch 210/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3912 - accuracy: 0.9618 - val_loss: 0.4919 - val_accuracy: 0.9120
# Epoch 211/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3949 - accuracy: 0.9583 - val_loss: 0.5178 - val_accuracy: 0.8981
# Epoch 212/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3973 - accuracy: 0.9560 - val_loss: 0.4952 - val_accuracy: 0.9167
# Epoch 213/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3880 - accuracy: 0.9618 - val_loss: 0.4768 - val_accuracy: 0.9028
# Epoch 214/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3897 - accuracy: 0.9653 - val_loss: 0.4813 - val_accuracy: 0.9120
# Epoch 215/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3940 - accuracy: 0.9618 - val_loss: 0.4988 - val_accuracy: 0.9074
# Epoch 216/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4005 - accuracy: 0.9560 - val_loss: 0.4841 - val_accuracy: 0.9120
# Epoch 217/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3981 - accuracy: 0.9560 - val_loss: 0.4993 - val_accuracy: 0.9120
# Epoch 218/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4048 - accuracy: 0.9514 - val_loss: 0.5040 - val_accuracy: 0.9028
# Epoch 219/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3890 - accuracy: 0.9618 - val_loss: 0.4804 - val_accuracy: 0.9120
# Epoch 220/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3892 - accuracy: 0.9641 - val_loss: 0.4952 - val_accuracy: 0.9120
# Epoch 221/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3961 - accuracy: 0.9583 - val_loss: 0.5059 - val_accuracy: 0.9028
# Epoch 222/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3928 - accuracy: 0.9606 - val_loss: 0.5056 - val_accuracy: 0.9028
# Epoch 223/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3886 - accuracy: 0.9606 - val_loss: 0.4966 - val_accuracy: 0.9074
# Epoch 224/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3840 - accuracy: 0.9664 - val_loss: 0.4978 - val_accuracy: 0.9074
# Epoch 225/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3880 - accuracy: 0.9618 - val_loss: 0.5197 - val_accuracy: 0.9167
# Epoch 226/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3844 - accuracy: 0.9630 - val_loss: 0.4865 - val_accuracy: 0.9120
# Epoch 227/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3845 - accuracy: 0.9630 - val_loss: 0.4773 - val_accuracy: 0.9167
# Epoch 228/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3906 - accuracy: 0.9676 - val_loss: 0.4887 - val_accuracy: 0.9259
# Epoch 229/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3877 - accuracy: 0.9630 - val_loss: 0.4921 - val_accuracy: 0.8935
# Epoch 230/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4016 - accuracy: 0.9525 - val_loss: 0.5020 - val_accuracy: 0.9074
# Epoch 231/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3909 - accuracy: 0.9595 - val_loss: 0.4831 - val_accuracy: 0.9120
# Epoch 232/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3854 - accuracy: 0.9618 - val_loss: 0.4812 - val_accuracy: 0.9213
# Epoch 233/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3844 - accuracy: 0.9641 - val_loss: 0.4856 - val_accuracy: 0.9167
# Epoch 234/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3970 - accuracy: 0.9630 - val_loss: 0.4883 - val_accuracy: 0.9167
# Epoch 235/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3851 - accuracy: 0.9630 - val_loss: 0.4899 - val_accuracy: 0.9213
# Epoch 236/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3977 - accuracy: 0.9606 - val_loss: 0.4956 - val_accuracy: 0.9028
# Epoch 237/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3900 - accuracy: 0.9618 - val_loss: 0.5046 - val_accuracy: 0.9074
# Epoch 238/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3952 - accuracy: 0.9583 - val_loss: 0.4980 - val_accuracy: 0.9028
# Epoch 239/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3899 - accuracy: 0.9595 - val_loss: 0.4888 - val_accuracy: 0.9120
# Epoch 240/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3848 - accuracy: 0.9653 - val_loss: 0.4864 - val_accuracy: 0.9120
# Epoch 241/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3842 - accuracy: 0.9653 - val_loss: 0.4820 - val_accuracy: 0.9120
# Epoch 242/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3892 - accuracy: 0.9618 - val_loss: 0.4904 - val_accuracy: 0.9074
# Epoch 243/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3953 - accuracy: 0.9583 - val_loss: 0.4812 - val_accuracy: 0.9120
# Epoch 244/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3902 - accuracy: 0.9618 - val_loss: 0.4998 - val_accuracy: 0.8935
# Epoch 245/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3899 - accuracy: 0.9641 - val_loss: 0.4886 - val_accuracy: 0.9120
# Epoch 246/250
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3837 - accuracy: 0.9641 - val_loss: 0.4926 - val_accuracy: 0.9074
# Epoch 247/250
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3897 - accuracy: 0.9664 - val_loss: 0.4889 - val_accuracy: 0.9074
# Epoch 248/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3864 - accuracy: 0.9664 - val_loss: 0.5037 - val_accuracy: 0.9074
# Epoch 249/250
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3918 - accuracy: 0.9618 - val_loss: 0.4797 - val_accuracy: 0.9167
# Epoch 250/250
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3845 - accuracy: 0.9699 - val_loss: 0.5209 - val_accuracy: 0.8843

# %%
# Now let's test your model in the test data to see how it works.
test_loss, test_acc = model.evaluate(X_test,  Y_test)
model.save('my_model.h5')
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6613 - accuracy: 0.7833

# %% [markdown]
# **Expected output**
# accuracy shall be higher than 0.75.
#
# Congratulations! You have finised the assignment and built a model that recognizes SIGN language with almost 75% accuracy on the test set. You probably want to save your hard work, the trained model, using `model.save('my_model.h5')`. You can later load the saved model by the command `model = load_model('my_model.h5')`
#
# Once again, here's a thumbs up for your work!

# %%
# %pylab inline
import matplotlib.image as mpimg
img = mpimg.imread('images/thumbs_up.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Challenge**: Can you try to adjust the hyper-parameters (learning_rate, epochs, batch_size, kernel_regularizer) to improve the accuracy to 85%?
#
# If you wish, feel free to play around with this dataset further. You can actually improve its accuracy by spending more time tuning the hyperparameters, or using regularization (as this model clearly has a high variance). It's quite easy to specify the regularization in the model. Simply, add option 'kernel_regularizer=tf.keras.regularizers.L2(0.001),' to the Conv and Dense layer
